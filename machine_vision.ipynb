# %% [markdown]
# <a href="https://colab.research.google.com/github/smidolt/Ip/blob/main/machine_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow
import tensorflow_datasets
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
import matplotlib.pyplot as plt
from google.colab import files

# %%
SIZE = 224

# %%
train, _ = tensorflow_datasets.load('cats_vs_dogs', split = ['train[:100%]'],with_info=True, as_supervised=True)

# %%
for img, _ in train[0].take(12):
  plt.figure()
  plt.imshow(img)
